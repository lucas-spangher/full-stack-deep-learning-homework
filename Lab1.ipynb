# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas-spangher/full-stack-deep-learning-homework/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/full-stack-deep-learning/fsdl-text-recognizer-2021-labs
# %cd fsdl-text-recognizer-2021-labs
# !pip install pytorch_lightning
# %env PYTHONPATH=.:$PYTHONPATH
# Out:
# Cloning into 'fsdl-text-recognizer-2021-labs'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 122 (delta 32), reused 114 (delta 24), pack-reused 0
# Receiving objects: 100% (122/122), 2.68 MiB | 32.72 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/fsdl-text-recognizer-2021-labs/lab1/fsdl-text-recognizer-2021-labs
# ...
# env: PYTHONPATH=.:$PYTHONPATH

# %%
# %cd lab1
# Out:
# /content/fsdl-text-recognizer-2021-labs/lab1/fsdl-text-recognizer-2021-labs/lab1

# %%
# %pwd
# Out:
# '/content/fsdl-text-recognizer-2021-labs/lab1/fsdl-text-recognizer-2021-labs/lab1'

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...
# 9920512it [00:00, 39472858.89it/s]
# Extracting /content/fsdl-text-recognizer-2021-labs/data/downloaded/MNIST/raw/train-images-idx3-ubyte.gz to /content/fsdl-text-recognizer-2021-labs/data/downloaded/MNIST/raw
# ...
# 32768it [00:00, 615404.73it/s]
# Extracting /content/fsdl-text-recognizer-2021-labs/data/downloaded/MNIST/raw/train-labels-idx1-ubyte.gz to /content/fsdl-text-recognizer-2021-labs/data/downloaded/MNIST/raw
# ...
# 1654784it [00:00, 11360561.93it/s]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=10 --gpus=1
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:03:47.020202: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 936 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 936 K     Trainable params
# 0         Non-trainable params
# 936 K     Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 42.10it/s, loss=0.212, v_num=1, val_loss=2.33, val_acc=0.0664]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=24 --fc2=48
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:07:35.749825: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 20.5 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 20.5 K    Trainable params
# 0         Non-trainable params
# 20.5 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 42.10it/s, loss=0.943, v_num=2, val_loss=2.3, val_acc=0.129]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=15 --gpus=1
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:10:08.105381: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 936 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 936 K     Trainable params
# 0         Non-trainable params
# 936 K     Total params
# Epoch 0:  91% 430/470 [00:11<00:01, 38.69it/s, loss=0.212, v_num=4, val_loss=2.33, val_acc=0.0664]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=24 --fc2=24
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:17:21.508630: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 19.7 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 42.27it/s, loss=1.05, v_num=5, val_loss=2.32, val_acc=0.105]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=24 --fc2=48
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:18:27.950878: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 20.5 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 20.5 K    Trainable params
# 0         Non-trainable params
# 20.5 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 41.80it/s, loss=0.943, v_num=6, val_loss=2.3, val_acc=0.129]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=24 --fc2=96
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:19:32.655163: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 22.2 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 22.2 K    Trainable params
# 0         Non-trainable params
# 22.2 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:01, 39.90it/s, loss=0.811, v_num=7, val_loss=2.32, val_acc=0.082]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=48 --fc2=24
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:20:40.201467: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 39.1 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 39.1 K    Trainable params
# 0         Non-trainable params
# 39.1 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 40.65it/s, loss=0.833, v_num=8, val_loss=2.3, val_acc=0.113]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=48 --fc2=48
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:21:47.880124: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 40.5 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 40.5 K    Trainable params
# 0         Non-trainable params
# 40.5 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:01, 39.22it/s, loss=0.694, v_num=9, val_loss=2.31, val_acc=0.113]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=48 --fc2=96
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:22:56.539981: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 43.4 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 43.4 K    Trainable params
# 0         Non-trainable params
# 43.4 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:01, 39.95it/s, loss=0.543, v_num=10, val_loss=2.31, val_acc=0.113]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=24
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:24:04.541815: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 77.9 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 77.9 K    Trainable params
# 0         Non-trainable params
# 77.9 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 42.14it/s, loss=0.644, v_num=11, val_loss=2.31, val_acc=0.121]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=48
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:25:12.417059: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 80.5 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 80.5 K    Trainable params
# 0         Non-trainable params
# 80.5 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 40.38it/s, loss=0.494, v_num=12, val_loss=2.3, val_acc=0.102]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 05:46:15.548345: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 85.6 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 42.39it/s, loss=0.445, v_num=13, val_loss=2.31, val_acc=0.102]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96 --subsample_fraction=.25
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 06:01:59.857930: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 85.6 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 40.73it/s, loss=0.445, v_num=14, val_loss=2.31, val_acc=0.102]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96 --subsample_fraction=.5
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 06:03:09.142028: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 85.6 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 41.58it/s, loss=0.445, v_num=15, val_loss=2.31, val_acc=0.102]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96 --subsample_fraction=.75
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 06:04:14.769057: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 85.6 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# Epoch 0:  91% 430/470 [00:10<00:00, 41.59it/s, loss=0.445, v_num=16, val_loss=2.31, val_acc=0.102]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96 --subsample_fraction=.25 --batch_size=32
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 06:05:22.601432: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 85.6 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# Epoch 0:  92% 1719/1876 [00:16<00:01, 106.97it/s, loss=0.31, v_num=17, val_loss=2.32, val_acc=0.0938]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96 --subsample_fraction=.25 --batch_size=512
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 06:06:59.165352: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 85.6 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# Epoch 0:  92% 108/118 [00:09<00:00, 11.50it/s, loss=0.537, v_num=18, val_loss=2.3, val_acc=0.135]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96 --subsample_fraction=.25 --batch_size=4096
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...
# 9920512it [00:00, 24289658.95it/s]
# Extracting /content/fsdl-text-recognizer-2021-labs/data/downloaded/MNIST/raw/train-images-idx3-ubyte.gz to /content/fsdl-text-recognizer-2021-labs/data/downloaded/MNIST/raw
# ...
# 32768it [00:00, 356356.74it/s]
# Extracting /content/fsdl-text-recognizer-2021-labs/data/downloaded/MNIST/raw/train-labels-idx1-ubyte.gz to /content/fsdl-text-recognizer-2021-labs/data/downloaded/MNIST/raw
# ...
# 1654784it [00:00, 10724676.05it/s]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96 --subsample_fraction=.25 --batch_size=8
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 06:10:20.583544: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 85.6 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# Epoch 0:  92% 6875/7500 [00:40<00:03, 171.84it/s, loss=0.344, v_num=20, val_loss=2.32, val_acc=0]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1 --fc1=96 --fc2=96 --subsample_fraction=.25 --batch_size=2
# Out:
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 06:14:00.886514: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 85.6 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 85.6 K    Trainable params
# 0         Non-trainable params
# 85.6 K    Total params
# Epoch 0:  92% 27500/30000 [02:09<00:11, 212.05it/s, loss=0.322, v_num=21, val_loss=2.35, val_acc=0]
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1
# Out:
# --------------------
# modified MLP
# --------------------
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 20:38:55.863617: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 970 K
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 970 K     Trainable params
# 0         Non-trainable params
# 970 K     Total params
# ...

# %%
# !python3 training/run_experiment.py --model_class=MLP --data_class=MNIST --max_epochs=5 --gpus=1
# Out:
# --------------------
# modified MLP
# no dropout
# --------------------
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:49: UserWarning: You have set progress_bar_refresh_rate < 20 on Google Colab. This may crash. Consider using progress_bar_refresh_rate >= 20 in Trainer.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-26 20:50:14.338795: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | MLP      | 1.0 M
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# 3 | test_acc  | Accuracy | 0
# ---------------------------------------
# 1.0 M     Trainable params
# 0         Non-trainable params
# 1.0 M     Total params
# ...
